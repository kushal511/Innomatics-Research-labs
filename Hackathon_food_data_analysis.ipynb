# %% [markdown]
# Hackathon food data analysis

# %% [markdown]
# Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib as plt
import seaborn as sns

# %% [markdown]
# Read the Data

# %%
df=pd.read_csv('/content/drive/MyDrive/restaurant_data.csv', encoding='cp437',sep=',',engine='python')
df
# Out:
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# 3      1st Floor, Annakuteera, 3rd Stage, Banashankar...
# 4      10, 3rd Floor, Lakshmi Associates, Gandhi Baza...
# ...                                                  ...
# 43996                         Cunningham Road, Bangalore
# 43997    36, Vittal Mallya Road, Lavelle Road, Bangalore
# 43998  L1-08 Skywalk, 5/1, Near Body Craft, Assaye Ro...
# 43999       145, 8th Main Road, Vasanth Nagar, Bangalore
# 44000  57/1, 1st Floor, Jayalaxmi Chambers, Next to O...
#
#                         name online_order book_table    rate no_of_votes  \
# 0                      Jalsa          Yes        Yes   4.1/5         775
# 1             Spice Elephant          Yes         No   4.1/5         787
# ...

# %%
df_new = df.iloc[:, 0:16]
df_new
# Out:
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# 3      1st Floor, Annakuteera, 3rd Stage, Banashankar...
# 4      10, 3rd Floor, Lakshmi Associates, Gandhi Baza...
# ...                                                  ...
# 43996                         Cunningham Road, Bangalore
# 43997    36, Vittal Mallya Road, Lavelle Road, Bangalore
# 43998  L1-08 Skywalk, 5/1, Near Body Craft, Assaye Ro...
# 43999       145, 8th Main Road, Vasanth Nagar, Bangalore
# 44000  57/1, 1st Floor, Jayalaxmi Chambers, Next to O...
#
#                         name online_order book_table    rate no_of_votes  \
# 0                      Jalsa          Yes        Yes   4.1/5         775
# 1             Spice Elephant          Yes         No   4.1/5         787
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# 3      1st Floor, Annakuteera, 3rd Stage, Banashankar...
# 4      10, 3rd Floor, Lakshmi Associates, Gandhi Baza...
# ...                                                  ...
# 43996                         Cunningham Road, Bangalore
# 43997    36, Vittal Mallya Road, Lavelle Road, Bangalore
# 43998  L1-08 Skywalk, 5/1, Near Body Craft, Assaye Ro...
# 43999       145, 8th Main Road, Vasanth Nagar, Bangalore
# 44000  57/1, 1st Floor, Jayalaxmi Chambers, Next to O...
#
#                         name online_order book_table    rate no_of_votes  \
# 0                      Jalsa          Yes        Yes   4.1/5         775
# 1             Spice Elephant          Yes         No   4.1/5         787
# ...

# %%
df.columns
# Out:
# Index(['address', 'name', 'online_order', 'book_table', 'rate', 'no_of_votes',
#        'Mobile', 'location', 'rest_type', 'dish_liked',
#        ...
#        'Unnamed: 4149', 'Unnamed: 4150', 'Unnamed: 4151', 'Unnamed: 4152',
#        'Unnamed: 4153', 'Unnamed: 4154', 'Unnamed: 4155', 'Unnamed: 4156',
#        'Unnamed: 4157', 'Unnamed: 4158'],
#       dtype='object', length=4159)

# %%
df.drop(df.iloc[:, 15:], inplace=True, axis=1)

# %%
df
# Out:
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# 3      1st Floor, Annakuteera, 3rd Stage, Banashankar...
# 4      10, 3rd Floor, Lakshmi Associates, Gandhi Baza...
# ...                                                  ...
# 43996                         Cunningham Road, Bangalore
# 43997    36, Vittal Mallya Road, Lavelle Road, Bangalore
# 43998  L1-08 Skywalk, 5/1, Near Body Craft, Assaye Ro...
# 43999       145, 8th Main Road, Vasanth Nagar, Bangalore
# 44000  57/1, 1st Floor, Jayalaxmi Chambers, Next to O...
#
#                         name online_order book_table    rate no_of_votes  \
# 0                      Jalsa          Yes        Yes   4.1/5         775
# 1             Spice Elephant          Yes         No   4.1/5         787
# ...

# %%
df.shape
# Out:
# (44001, 15)

# %%
df.describe()
# Out:
#               address           name online_order book_table   rate  \
# count           41027          41028        41028      41005  35371
# unique          10670           9512         1864       2031   2049
# top      ('Rated 4.0'   ('Rated 4.0'          Yes         No  3.9/5
# freq              555            193        23422      33501   2098
#
#        no_of_votes         Mobile location    rest_type     dish_liked  \
# count        40992          40167    40961        40806          20279
# unique        4000          13523     2087         2082           6136
# top              0   ('Rated 4.0'      BTM  Quick Bites   ('Rated 4.0'
# freq          7511            271     5118        14249            257
#
#             cuisines approx_cost(for two people) reviews_list menu_item  \
# count          40921                       40745        40936     37990
# unique          4333                        2045        18540      8221
# ...

# %%
df.isnull().sum()
# Out:
# address                         2974
# name                            2973
# online_order                    2973
# book_table                      2996
# rate                            8630
# no_of_votes                     3009
# Mobile                          3834
# location                        3040
# rest_type                       3195
# dish_liked                     23722
# cuisines                        3080
# approx_cost(for two people)     3256
# reviews_list                    3065
# menu_item                       6011
# listed_in(type)                 6017
# dtype: int64

# %%
df.dropna(inplace =True)

# %%
df.isnull().sum()
# Out:
# address                        0
# name                           0
# online_order                   0
# book_table                     0
# rate                           0
# no_of_votes                    0
# Mobile                         0
# location                       0
# rest_type                      0
# dish_liked                     0
# cuisines                       0
# approx_cost(for two people)    0
# reviews_list                   0
# menu_item                      0
# listed_in(type)                0
# dtype: int64

# %% [markdown]
# After cleaning data

# %%
df
# Out:
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# 3      1st Floor, Annakuteera, 3rd Stage, Banashankar...
# 4      10, 3rd Floor, Lakshmi Associates, Gandhi Baza...
# ...                                                  ...
# 43992   \nI placed an order with the Ulsoor branch at...
# 43993     42 Vittal Mallya Road, Lavelle Road, Bangalore
# 43995  Sree Kanteerava Outdoor Stadium Main Gate, Kas...
# 43997    36, Vittal Mallya Road, Lavelle Road, Bangalore
# 43998  L1-08 Skywalk, 5/1, Near Body Craft, Assaye Ro...
#
#                                                     name  \
# 0                                                  Jalsa
# 1                                         Spice Elephant
# 2                                        San Churro Cafe
# ...

# %%
df['approx_cost(for two people)']=df['approx_cost(for two people)'].apply(lambda x:x.replace('?',''))
df['approx_cost(for two people)']
# Out:
# 0                                                   800.00
# 1                                                   800.00
# 2                                                   800.00
# 3                                                   300.00
# 4                                                   600.00
#                                ...
# 43992     ""RATED\n  Worst placed to order. Please do n...
# 43993                                               300.00
# 43995                                               600.00
# 43997                                             1,200.00
# 43998                                               800.00
# Name: approx_cost(for two people), Length: 17127, dtype: object

# %%
df
# Out:
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# 3      1st Floor, Annakuteera, 3rd Stage, Banashankar...
# 4      10, 3rd Floor, Lakshmi Associates, Gandhi Baza...
# ...                                                  ...
# 43992   \nI placed an order with the Ulsoor branch at...
# 43993     42 Vittal Mallya Road, Lavelle Road, Bangalore
# 43995  Sree Kanteerava Outdoor Stadium Main Gate, Kas...
# 43997    36, Vittal Mallya Road, Lavelle Road, Bangalore
# 43998  L1-08 Skywalk, 5/1, Near Body Craft, Assaye Ro...
#
#                                                     name  \
# 0                                                  Jalsa
# 1                                         Spice Elephant
# 2                                        San Churro Cafe
# ...

# %% [markdown]
# Data Analysis

# %%
df['name'].describe()
# Out:
# count             17127
# unique             4702
# top        ('Rated 4.0'
# freq                190
# Name: name, dtype: object

# %%
df['location'].describe()
# Out:
# count     17127
# unique     2044
# top         BTM
# freq       1319
# Name: location, dtype: object

# %%
df['online_order'].describe()
# Out:
# count     17127
# unique     1787
# top         Yes
# freq      10711
# Name: online_order, dtype: object

# %%
df[(df['online_order']=='Yes')].count()
# Out:
# address                        10711
# name                           10711
# online_order                   10711
# book_table                     10711
# rate                           10711
# no_of_votes                    10711
# Mobile                         10711
# location                       10711
# rest_type                      10711
# dish_liked                     10711
# cuisines                       10711
# approx_cost(for two people)    10711
# reviews_list                   10711
# menu_item                      10711
# listed_in(type)                10711
# dtype: int64

# %%
df[(df['online_order']=='No')].count()
# Out:
# address                        3568
# name                           3568
# online_order                   3568
# book_table                     3568
# rate                           3568
# no_of_votes                    3568
# Mobile                         3568
# location                       3568
# rest_type                      3568
# dish_liked                     3568
# cuisines                       3568
# approx_cost(for two people)    3568
# reviews_list                   3568
# menu_item                      3568
# listed_in(type)                3568
# dtype: int64

# %%
df['book_table'].describe()
# Out:
# count     17127
# unique     1969
# top          No
# freq      11223
# Name: book_table, dtype: object

# %%
df['rate'].describe()
# Out:
# count     17127
# unique     1993
# top       3.9/5
# freq       1587
# Name: rate, dtype: object

# %%
df['no_of_votes'].describe()
# Out:
# count             17127
# unique             3508
# top        ('Rated 4.0'
# freq                247
# Name: no_of_votes, dtype: object

# %%
df['rest_type'].describe()
# Out:
# count             17127
# unique             2018
# top       Casual Dining
# freq               4599
# Name: rest_type, dtype: object

# %%
df['cuisines'].describe()
# Out:
# count            17127
# unique            3336
# top       North Indian
# freq               714
# Name: cuisines, dtype: object

# %%
df['approx_cost(for two people)'].describe()
# Out:
# count      17127
# unique      2009
# top       400.00
# freq        1732
# Name: approx_cost(for two people), dtype: object

# %%
df['location'].values
# Out:
# array(['Banashankari', 'Banashankari', 'Banashankari', ...,
#        'Lavelle Road', 'Lavelle Road', 'Ulsoor'], dtype=object)

# %%
df['rest_type'].values
# Out:
# array(['Casual Dining', 'Casual Dining', 'Cafe, Casual Dining', ...,
#        'Casual Dining', 'Pub', 'Cafe'], dtype=object)

# %% [markdown]
# Data Visualization

# %% [markdown]
# bar plot

# %%
crosstb = pd.crosstab(df.location,df.rate)
barplot = crosstb.plot.bar()

# %%
crosstb = pd.crosstab(df.location,df.online_order)
barplot = crosstb.plot.bar()

# %%
crosstb = pd.crosstab(df.location,df.book_table)
barplot = crosstb.plot.bar()

# %%
crosstb = pd.crosstab(df.online_order,df.rate)
barplot = crosstb.plot.bar()
